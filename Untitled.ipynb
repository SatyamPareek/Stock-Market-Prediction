# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df_train=pd.read_csv('GOOG_train.csv')
df_test=pd.read_csv("GOOG_test.csv")
df_train.head()
# Out:
#          Date        Open        High        Low       Close   Adj Close  \
# 0  03-01-2005   98.331429  101.439781  97.365051  100.976517  100.976517
# 1  04-01-2005  100.323959  101.086105  96.378746   96.886841   96.886841
# 2  05-01-2005   96.363808   98.082359  95.756081   96.393692   96.393692
# 3  06-01-2005   97.175758   97.584229  93.509506   93.922951   93.922951
# 4  07-01-2005   94.964050   96.762314  94.037521   96.563057   96.563057
#
#      Volume  Dollar
# 0  31807176    44.1
# 1  27614921    44.1
# 2  16534946    44.1
# 3  20852067    44.1
# 4  19398238    44.1

# %%
df_test.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 1072  05-04-2022  2867.989990  2871.800049  2818.870117  2821.260010
# 1073  06-04-2022  2783.229980  2796.969971  2728.362061  2743.520020
# 1074  07-04-2022  2732.360107  2754.030029  2697.145020  2729.300049
# 1075  08-04-2022  2725.000000  2725.000000  2675.050049  2680.209961
# 1076  11-04-2022  2658.000000  2658.783936  2592.350098  2595.929932
#
#         Adj Close   Volume  Dollar
# 1072  2821.260010   962800   76.05
# 1073  2743.520020  1178700   76.05
# 1074  2729.300049   972400   76.05
# 1075  2680.209961   821000   76.05
# 1076  2595.929932  1209400   76.05

# %%
train_dates=pd.to_datetime(df_train['Date'])
test_dates=pd.to_datetime(df_test['Date'])
# Out:
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-01-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-02-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-03-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-04-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-05-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-06-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-07-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-08-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-09-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-10-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-11-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-12-2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '25-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '26-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-01-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-02-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '14-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '15-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '16-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '20-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '21-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '22-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '23-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '24-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '27-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '28-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '29-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '30-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '31-03-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '13-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '17-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '18-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:1: UserWarning: Parsing '19-04-2006' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train_dates=pd.to_datetime(df_train['Date'])
# ...
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '26-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '27-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '28-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '29-10-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '15-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '16-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '17-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '18-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '19-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '22-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '23-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '24-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '26-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '29-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '30-11-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '13-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '14-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '15-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '16-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '17-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '20-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '21-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '22-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '23-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '27-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '28-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '29-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '30-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '31-12-2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '13-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '14-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '18-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '19-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '20-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '21-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '24-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '25-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '26-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '27-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '28-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '31-01-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '14-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '15-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '16-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '17-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '18-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '22-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '23-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '24-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '25-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '28-02-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '14-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '15-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '16-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '17-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '18-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '21-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '22-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '23-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '24-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '25-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '28-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '29-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '30-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\3201084315.py:2: UserWarning: Parsing '31-03-2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   test_dates=pd.to_datetime(df_test['Date'])

# %%
features=list(df_train)[1:8]
features
# Out:
# ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Dollar']

# %%
df_for_training=df_train[features].astype(float)

# %%
print(df_for_training)
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0       98.331429   101.439781    97.365051   100.976517   100.976517
# 1      100.323959   101.086105    96.378746    96.886841    96.886841
# 2       96.363808    98.082359    95.756081    96.393692    96.393692
# 3       97.175758    97.584229    93.509506    93.922951    93.922951
# 4       94.964050    96.762314    94.037521    96.563057    96.563057
# ...           ...          ...          ...          ...          ...
# 3267  1061.109985  1064.199951  1059.439941  1060.119995  1060.119995
# 3268  1058.069946  1060.119995  1050.199951  1056.739990  1056.739990
# 3269  1057.390015  1058.369995  1048.050049  1049.369995  1049.369995
# 3270  1051.599976  1054.750000  1044.770020  1048.140015  1048.140015
# 3271  1046.719971  1049.699951  1044.900024  1046.400024  1046.400024
#
#           Volume  Dollar
# 0     31807176.0   44.10
# 1     27614921.0   44.10
# 2     16534946.0   44.10
# 3     20852067.0   44.10
# 4     19398238.0   44.10
# ...          ...     ...
# 3267    755100.0   67.79
# 3268    760600.0   67.79
# 3269   1271900.0   67.79
# 3270    837100.0   67.79
# 3271    887500.0   67.79
#
# [3272 rows x 7 columns]

# %%
df_for_testing=df_test[features].astype(float)

# %%
df_for_testing
# Out:
#              Open         High          Low        Close    Adj Close  \
# 0     1048.339966  1066.939941  1045.229980  1065.000000  1065.000000
# 1     1064.310059  1086.290039  1063.209961  1082.479980  1082.479980
# 2     1088.000000  1093.569946  1084.001953  1086.400024  1086.400024
# 3     1094.000000  1104.250000  1092.000000  1102.229980  1102.229980
# 4     1102.229980  1111.270020  1101.619995  1106.939941  1106.939941
# ...           ...          ...          ...          ...          ...
# 1072  2867.989990  2871.800049  2818.870117  2821.260010  2821.260010
# 1073  2783.229980  2796.969971  2728.362061  2743.520020  2743.520020
# 1074  2732.360107  2754.030029  2697.145020  2729.300049  2729.300049
# 1075  2725.000000  2725.000000  2675.050049  2680.209961  2680.209961
# 1076  2658.000000  2658.783936  2592.350098  2595.929932  2595.929932
#
#          Volume  Dollar
# 0     1237600.0   70.09
# 1     1430200.0   70.09
# 2     1004600.0   70.09
# 3     1279100.0   70.09
# 4     1047600.0   70.09
# ...         ...     ...
# 1072   962800.0   76.05
# 1073  1178700.0   76.05
# 1074   972400.0   76.05
# 1075   821000.0   76.05
# 1076  1209400.0   76.05
#
# [1077 rows x 7 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df_for_training_scaled=scaler.fit_transform(df_for_training)

# %%
trainX = []
trainY = []

n_past = 30  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
for i in range(n_past, len(df_for_training_scaled)):
    trainX.append(df_for_training_scaled[i - n_past:i])
    trainY.append(df_for_training_scaled[i, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))
# Out:
# trainX shape == (3242, 30, 7).
# trainY shape == (3242,).

# %%
from keras.models import Sequential
from keras.layers import Dense , Dropout
from keras.layers import LSTM

# %%
model = Sequential()
#first layer
model.add(LSTM(units=64, activation='tanh', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

#second layer
model.add(LSTM(units=60,activation='tanh',return_sequences=True))
model.add(Dropout(0.3))


#third layer
model.add(LSTM(units=80,activation='tanh',return_sequences=True))
model.add(Dropout(0.4))



#fourth layer
model.add(LSTM(units=100,activation='tanh'))
model.add(Dropout(0.5))


#last layer
model.add(Dense(units=1))

# %%
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            18432
#
#  dropout (Dropout)           (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 30, 60)            30000
#
#  dropout_1 (Dropout)         (None, 30, 60)            0
#
#  lstm_2 (LSTM)               (None, 30, 80)            45120
#
#  dropout_2 (Dropout)         (None, 30, 80)            0
#
#  lstm_3 (LSTM)               (None, 100)               72400
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 166,053
# Trainable params: 166,053
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model
history = model.fit(trainX, trainY, epochs=100, batch_size=64, validation_split=0.1, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
# Out:
# Epoch 1/100
# 46/46 [==============================] - 15s 167ms/step - loss: 0.0589 - val_loss: 0.2401
# Epoch 2/100
# 46/46 [==============================] - 6s 121ms/step - loss: 0.0200 - val_loss: 0.2160
# Epoch 3/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0168 - val_loss: 0.1741
# Epoch 4/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0165 - val_loss: 0.1385
# Epoch 5/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0158 - val_loss: 0.1388
# Epoch 6/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0156 - val_loss: 0.1085
# Epoch 7/100
# 46/46 [==============================] - 6s 121ms/step - loss: 0.0148 - val_loss: 0.1535
# Epoch 8/100
# 46/46 [==============================] - 6s 122ms/step - loss: 0.0142 - val_loss: 0.1050
# Epoch 9/100
# 46/46 [==============================] - 6s 120ms/step - loss: 0.0134 - val_loss: 0.0465
# Epoch 10/100
# 46/46 [==============================] - 6s 120ms/step - loss: 0.0132 - val_loss: 0.0648
# Epoch 11/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0157 - val_loss: 0.0674
# Epoch 12/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0144 - val_loss: 0.1485
# Epoch 13/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0130 - val_loss: 0.0777
# Epoch 14/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0135 - val_loss: 0.1120
# Epoch 15/100
# 46/46 [==============================] - 6s 124ms/step - loss: 0.0160 - val_loss: 0.1256
# Epoch 16/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0141 - val_loss: 0.2555
# Epoch 17/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0141 - val_loss: 0.0979
# Epoch 18/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0111 - val_loss: 0.0579
# Epoch 19/100
# 46/46 [==============================] - 6s 133ms/step - loss: 0.0111 - val_loss: 0.0811
# Epoch 20/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0129 - val_loss: 0.0959
# Epoch 21/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0125 - val_loss: 0.1219
# Epoch 22/100
# 46/46 [==============================] - 6s 131ms/step - loss: 0.0115 - val_loss: 0.1113
# Epoch 23/100
# 46/46 [==============================] - 6s 139ms/step - loss: 0.0118 - val_loss: 0.1528
# Epoch 24/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0116 - val_loss: 0.1074
# Epoch 25/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0107 - val_loss: 0.2123
# Epoch 26/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0116 - val_loss: 0.1980
# Epoch 27/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0108 - val_loss: 0.0953
# Epoch 28/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0105 - val_loss: 0.1550
# Epoch 29/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0119 - val_loss: 0.0930
# Epoch 30/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0105 - val_loss: 0.1350
# Epoch 31/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0104 - val_loss: 0.1253
# Epoch 32/100
# 46/46 [==============================] - 6s 132ms/step - loss: 0.0104 - val_loss: 0.0978
# Epoch 33/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0104 - val_loss: 0.1110
# Epoch 34/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0108 - val_loss: 0.1978
# Epoch 35/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0105 - val_loss: 0.1609
# Epoch 36/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0104 - val_loss: 0.1313
# Epoch 37/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0102 - val_loss: 0.1162
# Epoch 38/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0101 - val_loss: 0.1171
# Epoch 39/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0101 - val_loss: 0.1934
# Epoch 40/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0102 - val_loss: 0.1417
# Epoch 41/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0103 - val_loss: 0.1285
# Epoch 42/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0104 - val_loss: 0.1934
# Epoch 43/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0108 - val_loss: 0.1612
# Epoch 44/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0100 - val_loss: 0.1963
# Epoch 45/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0098 - val_loss: 0.2889
# Epoch 46/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0103 - val_loss: 0.1891
# Epoch 47/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0114 - val_loss: 0.2810
# Epoch 48/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0113 - val_loss: 0.2553
# Epoch 49/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0101 - val_loss: 0.2224
# Epoch 50/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0091 - val_loss: 0.2536
# Epoch 51/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0092 - val_loss: 0.2989
# Epoch 52/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0088 - val_loss: 0.1630
# Epoch 53/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0091 - val_loss: 0.1757
# Epoch 54/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0098 - val_loss: 0.1861
# Epoch 55/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0099 - val_loss: 0.1307
# Epoch 56/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0091 - val_loss: 0.2447
# Epoch 57/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0097 - val_loss: 0.2501
# Epoch 58/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0088 - val_loss: 0.2297
# Epoch 59/100
# 46/46 [==============================] - 6s 129ms/step - loss: 0.0099 - val_loss: 0.2184
# Epoch 60/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0088 - val_loss: 0.2352
# Epoch 61/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0094 - val_loss: 0.2006
# Epoch 62/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0096 - val_loss: 0.2514
# Epoch 63/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0087 - val_loss: 0.2327
# Epoch 64/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0086 - val_loss: 0.2641
# Epoch 65/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0100 - val_loss: 0.1956
# Epoch 66/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0086 - val_loss: 0.2039
# Epoch 67/100
# 46/46 [==============================] - 6s 127ms/step - loss: 0.0096 - val_loss: 0.2041
# Epoch 68/100
# 46/46 [==============================] - 6s 126ms/step - loss: 0.0087 - val_loss: 0.2171
# Epoch 69/100
# 46/46 [==============================] - 7s 142ms/step - loss: 0.0097 - val_loss: 0.3000
# Epoch 70/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0086 - val_loss: 0.2204
# Epoch 71/100
# 46/46 [==============================] - 6s 125ms/step - loss: 0.0083 - val_loss: 0.3102
# Epoch 72/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0083 - val_loss: 0.2316
# Epoch 73/100
# 46/46 [==============================] - 6s 131ms/step - loss: 0.0082 - val_loss: 0.2248
# Epoch 74/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0085 - val_loss: 0.2000
# Epoch 75/100
# 46/46 [==============================] - 6s 132ms/step - loss: 0.0088 - val_loss: 0.2600
# Epoch 76/100
# 46/46 [==============================] - 6s 130ms/step - loss: 0.0086 - val_loss: 0.2526
# Epoch 77/100
# 46/46 [==============================] - 6s 128ms/step - loss: 0.0094 - val_loss: 0.3282
# Epoch 78/100
# 46/46 [==============================] - 6s 122ms/step - loss: 0.0087 - val_loss: 0.2719
# Epoch 79/100
# 46/46 [==============================] - 5s 110ms/step - loss: 0.0084 - val_loss: 0.2962
# Epoch 80/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0084 - val_loss: 0.2466
# Epoch 81/100
# 46/46 [==============================] - 5s 107ms/step - loss: 0.0087 - val_loss: 0.2867
# Epoch 82/100
# 46/46 [==============================] - 5s 107ms/step - loss: 0.0083 - val_loss: 0.1875
# Epoch 83/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0083 - val_loss: 0.2490
# Epoch 84/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0087 - val_loss: 0.3234
# Epoch 85/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0088 - val_loss: 0.2596
# Epoch 86/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0082 - val_loss: 0.2264
# Epoch 87/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0088 - val_loss: 0.2201
# Epoch 88/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0089 - val_loss: 0.2995
# Epoch 89/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0082 - val_loss: 0.3118
# Epoch 90/100
# 46/46 [==============================] - 5s 107ms/step - loss: 0.0083 - val_loss: 0.3848
# Epoch 91/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0089 - val_loss: 0.2746
# Epoch 92/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0087 - val_loss: 0.3530
# Epoch 93/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0084 - val_loss: 0.2613
# Epoch 94/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0084 - val_loss: 0.2800
# Epoch 95/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0086 - val_loss: 0.3345
# Epoch 96/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0089 - val_loss: 0.3712
# Epoch 97/100
# 46/46 [==============================] - 5s 106ms/step - loss: 0.0084 - val_loss: 0.3382
# Epoch 98/100
# 46/46 [==============================] - 5s 105ms/step - loss: 0.0078 - val_loss: 0.2264
# Epoch 99/100
# 46/46 [==============================] - 5s 107ms/step - loss: 0.0082 - val_loss: 0.3568
# Epoch 100/100
# 46/46 [==============================] - 5s 107ms/step - loss: 0.0079 - val_loss: 0.3814

# %%
model.save('stock.h5')

# %%
df_for_testing.head()
# Out:
#           Open         High          Low        Close    Adj Close     Volume  \
# 0  1048.339966  1066.939941  1045.229980  1065.000000  1065.000000  1237600.0
# 1  1064.310059  1086.290039  1063.209961  1082.479980  1082.479980  1430200.0
# 2  1088.000000  1093.569946  1084.001953  1086.400024  1086.400024  1004600.0
# 3  1094.000000  1104.250000  1092.000000  1102.229980  1102.229980  1279100.0
# 4  1102.229980  1111.270020  1101.619995  1106.939941  1106.939941  1047600.0
#
#    Dollar
# 0   70.09
# 1   70.09
# 2   70.09
# 3   70.09
# 4   70.09

# %%
past_30_days=df_for_training.tail(30)

# %%
past_30_days
# Out:
#              Open         High          Low        Close    Adj Close  \
# 3242  1022.520020  1035.920044  1022.520020  1032.500000  1032.500000
# 3243  1034.010010  1034.420044  1017.750000  1019.090027  1019.090027
# 3244  1020.260010  1022.609985  1017.500000  1018.380005  1018.380005
# 3245  1023.309998  1035.109985  1022.655029  1034.489990  1034.489990
# 3246  1035.000000  1039.706055  1031.430054  1035.959961  1035.959961
# 3247  1035.869995  1043.177979  1035.000000  1040.609985  1040.609985
# 3248  1040.000000  1055.459961  1038.439941  1054.209961  1054.209961
# 3249  1055.089966  1062.375000  1040.000000  1047.410034  1047.410034
# 3250  1042.680054  1044.079956  1015.650024  1021.659973  1021.659973
# 3251  1022.369995  1028.489990  1015.000000  1021.409973  1021.409973
# 3252  1015.799988  1022.489990  1002.020020  1010.169983  1010.169983
# 3253  1012.659973  1016.099976   995.570007   998.679993   998.679993
# 3254   995.940002  1020.609985   988.280029  1005.150024  1005.150024
# 3255  1001.500000  1024.969971  1001.140015  1018.380005  1018.380005
# 3256  1020.429993  1034.239990  1018.070984  1030.930054  1030.930054
# 3257  1037.489990  1042.050049  1032.521973  1037.050049  1037.050049
# 3258  1035.500000  1043.800049  1032.050049  1041.099976  1041.099976
# 3259  1039.630005  1050.310059  1033.689941  1040.479980  1040.479980
# 3260  1046.119995  1046.665039  1038.380005  1040.609985  1040.609985
# 3261  1045.000000  1058.500000  1043.109985  1049.150024  1049.150024
# 3262  1054.609985  1067.619995  1049.500000  1064.189941  1064.189941
# 3263  1066.079956  1078.489990  1062.000000  1077.140015  1077.140015
# 3264  1075.199951  1076.839966  1063.550049  1070.680054  1070.680054
# 3265  1071.780029  1073.380005  1061.520020  1064.949951  1064.949951
# 3266  1064.949951  1069.329956  1061.793945  1063.630005  1063.630005
# 3267  1061.109985  1064.199951  1059.439941  1060.119995  1060.119995
# 3268  1058.069946  1060.119995  1050.199951  1056.739990  1056.739990
# 3269  1057.390015  1058.369995  1048.050049  1049.369995  1049.369995
# 3270  1051.599976  1054.750000  1044.770020  1048.140015  1048.140015
# 3271  1046.719971  1049.699951  1044.900024  1046.400024  1046.400024
#
#          Volume  Dollar
# 3242  1129700.0   67.79
# 3243  1397100.0   67.79
# 3244   953500.0   67.79
# 3245  1097000.0   67.79
# 3246   746300.0   67.79
# 3247   537000.0   67.79
# 3248  1307900.0   67.79
# 3249  1424400.0   67.79
# 3250  2459400.0   67.79
# 3251  1724000.0   67.79
# 3252  1909600.0   67.79
# 3253  1906400.0   67.79
# 3254  2067300.0   67.79
# 3255  1272000.0   67.79
# 3256  1458200.0   67.79
# 3257  1290800.0   67.79
# 3258  1192800.0   67.79
# 3259  1279500.0   67.79
# 3260  1282700.0   67.79
# 3261  1558700.0   67.79
# 3262  3275900.0   67.79
# 3263  1554600.0   67.79
# 3264  1338700.0   67.79
# 3265  1268600.0   67.79
# 3266   995700.0   67.79
# 3267   755100.0   67.79
# 3268   760600.0   67.79
# 3269  1271900.0   67.79
# 3270   837100.0   67.79
# 3271   887500.0   67.79

# %%
final_testing_df=past_30_days.append(df_for_testing,ignore_index=True)
# Out:
# C:\Users\MRHUB\AppData\Local\Temp\ipykernel_17564\150449065.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_testing_df=past_30_days.append(df_for_testing,ignore_index=True)

# %%
final_testing_df.head()
# Out:
#           Open         High          Low        Close    Adj Close     Volume  \
# 0  1022.520020  1035.920044  1022.520020  1032.500000  1032.500000  1129700.0
# 1  1034.010010  1034.420044  1017.750000  1019.090027  1019.090027  1397100.0
# 2  1020.260010  1022.609985  1017.500000  1018.380005  1018.380005   953500.0
# 3  1023.309998  1035.109985  1022.655029  1034.489990  1034.489990  1097000.0
# 4  1035.000000  1039.706055  1031.430054  1035.959961  1035.959961   746300.0
#
#    Dollar
# 0   67.79
# 1   67.79
# 2   67.79
# 3   67.79
# 4   67.79

# %%
final_testing_df.tail()
# Out:
#              Open         High          Low        Close    Adj Close  \
# 1102  2867.989990  2871.800049  2818.870117  2821.260010  2821.260010
# 1103  2783.229980  2796.969971  2728.362061  2743.520020  2743.520020
# 1104  2732.360107  2754.030029  2697.145020  2729.300049  2729.300049
# 1105  2725.000000  2725.000000  2675.050049  2680.209961  2680.209961
# 1106  2658.000000  2658.783936  2592.350098  2595.929932  2595.929932
#
#          Volume  Dollar
# 1102   962800.0   76.05
# 1103  1178700.0   76.05
# 1104   972400.0   76.05
# 1105   821000.0   76.05
# 1106  1209400.0   76.05

# %%
#now scale the testing data

input_data=scaler.fit_transform(final_testing_df)

# %%
input_data.shape
# Out:
# (1107, 7)

# %%
x_test=[]
y_test=[]

for i in range(30,input_data.shape[0]):
    x_test.append(input_data[i-30:i])
    y_test.append(input_data[i,0])

# %%
x_test,y_test=np.array(x_test),np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1077, 30, 7)
# (1077,)

# %%
#Making Predictons

y_pred=model.predict(x_test)

# %%
y_pred.shape
# Out:
# (1077, 1)

# %%
prediction_copies = np.repeat(y_pred, df_for_training.shape[1], axis=-1)
y_pred = scaler.inverse_transform(prediction_copies)[:,0]

# %%
y_test=y_test.reshape(-1,1)
testing_copies=np.repeat(y_test,df_for_training.shape[1],axis=-1)
y_test=scaler.inverse_transform(testing_copies)[:,0]

# %%
print(y_pred)
# Out:
# [1084.1652 1074.9727 1066.3374 ... 2647.3442 2640.1545 2631.1567]

# %%
print(y_test)
# Out:
# [1048.339966 1064.310059 1088.       ... 2732.360107 2725.
#  2658.      ]

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test,'b',label='Original Price')
plt.plot(y_pred,'r',label='Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
error=0
for i in range(1,1077):
    error+=abs(y_pred[i-1]-y_test[i-1])

mean=error/1077
mean
# Out:
# 50.9431614049334

# %%
y_test.max()
# Out:
# 3037.27002

# %%
y_test.min()
# Out:
# 973.900024

# %%
import math 
from sklearn.metrics import mean_squared_error
rmse=math.sqrt(mean_squared_error(y_test,y_pred))

# %%
rmse
# Out:
# 85.10235375789554

# %%
nrmse=rmse/(y_test.max()-y_test.min())
nrmse
# Out:
# 0.04124434973992689

# %%
error=[]
for i in range(1,y_test.shape[0]+1):
    error.append(abs(y_test[i-1]-y_pred[i-1]))

error=np.array(error)
error=error.reshape(-1,1)

# %%
y_test_classification=[]
y_pred_classification=[]

for i in range(1,y_test.shape[0]+1):
    y_test_classification.append(1)

# %%
y_test_classification=np.array(y_test_classification)
y_test_classification=y_test_classification.reshape(-1,1)

# %%
for i in range(1,y_test.shape[0]+1):
    if(((error[i-1]/y_test[i-1])*100)<=5):
        y_pred_classification.append(1)
    else:
        y_pred_classification.append(0)

y_pred_classification=np.array(y_pred_classification)
y_pred_classification=y_pred_classification.reshape(-1,1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(classification_report(y_pred_classification,y_test_classification))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       176
#            1       0.84      1.00      0.91       901
#
#     accuracy                           0.84      1077
#    macro avg       0.42      0.50      0.46      1077
# weighted avg       0.70      0.84      0.76      1077
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(confusion_matrix(y_pred_classification,y_test_classification))
# Out:
# [[  0 176]
#  [  0 901]]

# %%
accuracy=(901/1057)*100
accuracy
# Out:
# 85.24124881740775
